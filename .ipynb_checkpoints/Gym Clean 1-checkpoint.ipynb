# %%
# %pip install pandas

import pandas as pd

df = pd.read_csv("gym.csv")
# Out:
# Requirement already satisfied: pandas in c:\users\calum\appdata\local\programs\python\python312\lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\calum\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\calum\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\calum\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\calum\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
cols_dropped = ["Kcal", "Distance", "Duration", "Bodyweight"]

df = df.drop(columns = cols_dropped)

df = df[df["Reps"].notnull()]

df["Name"] = df["Name"].str.strip()
sorted(df["Name"].dropna().unique())

df = df[df["Workout End"].notnull()]

df=df.sort_values("Workout Start").reset_index(drop=True)
df["workout_id"] = df.groupby(["Workout Start", "Workout End"]).ngroup()
df["workout_id"] = df["workout_id"].astype(int)
df["workout_id"] = df["workout_id"] + 1
print(df["workout_id"].nunique(), "unique workouts")

df = df.reset_index(drop=True)
df["set_id"] = df.index + 1

df["exercise_id"] = pd.factorize(
    df["workout_id"].astype(str) + "_" + df["Exercise"]
)[0] + 1

df = df.rename(columns={
    "Workout Start": "workout_start",
    "Workout End": "workout_end",
    "Exercise": "exercise",
    "Weight": "weight",
    "Reps": "reps",
    "Notes": "notes",
    "Category": "category",
    "Name": "workout_name"
})

df["workout_start"] = pd.to_datetime(df["workout_start"])
df["workout_end"] = pd.to_datetime(df["workout_end"])

df.to_csv("staged_workouts.csv", index=False)
# Out:
# 797 unique workouts

# %%
import dlt

df2 = pd.read_csv("staged_workouts.csv")

pipeline = dlt.pipeline(
    pipeline_name = "gym",
    destination = "bigquery",
    dataset_name = "gym_raw"
)

load_info = pipeline.run(df2.to_dict(orient="records"), table_name = "workouts")
print(load_info)
# Out:
# ---------------------------------------------------------------------------
# ConfigFieldMissingException               Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:832, in Pipeline._sync_destination(self, destination, staging, dataset_name)
#     830 restored_schemas: Sequence[Schema] = None
# --> 832 remote_state = self._restore_state_from_destination()
#     834 # if remote state is newer or same
#     835 # TODO: check if remote_state["_state_version"] is not in 10 recent version. then we know remote is newer.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:1715, in Pipeline._restore_state_from_destination(self)
#    1714     schema = Schema(schema_name)
# -> 1715 with self._get_destination_clients(schema)[0] as job_client:
#    1716     if isinstance(job_client, WithStateSync):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:1464, in Pipeline._get_destination_clients(self, schema)
#    1456     raise PipelineConfigMissing(
#    1457         self.pipeline_name,
#    1458         "destination",
#    (...)
#    1461         " directly or via .dlt/config.toml file or environment variable.",
#    1462     )
# -> 1464 destination_client, staging_client = get_destination_clients(
#    1465     schema=schema or self.default_schema,
#    1466     destination=self._destination,
#    1467     destination_dataset_name=self.dataset_name,
#    1468     staging=self._staging,
#    1469     # in case of destination that does not need dataset name, we still must
#    1470     # provide one to staging
#    1471     # TODO: allow for separate staging_dataset_name, that will require to migrate pipeline state
#    1472     #   to store it.
#    1473     staging_dataset_name=self.dataset_name or self._make_dataset_name(None, self._staging),
#    1474     multi_dataset_default_schema_name=(
#    1475         self.default_schema_name if not self.config.use_single_dataset else None
#    1476     ),
#    1477 )
#    1479 if isinstance(destination_client.config, DestinationClientStagingConfiguration):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\dataset\utils.py:85, in get_destination_clients(schema, destination, destination_dataset_name, multi_dataset_default_schema_name, staging, staging_dataset_name)
#      84 # create instance with initial_config properly set
# ---> 85 client = destination.client(schema, initial_config)
#      86 return client, staging_client
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\common\destination\reference.py:187, in Destination.client(self, schema, initial_config)
#     186 """Returns a configured instance of the destination's job client"""
# --> 187 config = self.configuration(initial_config)
#     188 caps = self.capabilities(config, schema.naming)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\common\destination\reference.py:174, in Destination.configuration(self, initial_config, accept_partial)
#     172 """Get a fully resolved destination config from the initial config"""
# --> 174 config = resolve_configuration(
#     175     initial_config or self.spec(),
#     176     sections=(known_sections.DESTINATION, self.destination_name),
#     177     # already populated values will supersede resolved env config
#     178     explicit_value=self.config_params,
#     179     accept_partial=accept_partial,
#     180 )
#     181 return config
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\common\configuration\resolve.py:91, in resolve_configuration(config, sections, explicit_value, accept_partial)
#      89         log_traces(None, config.__section__, type(config), initial_value, None, traces)
# ---> 91 return _resolve_configuration(config, sections, (), explicit_value, accept_partial)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\common\configuration\resolve.py:199, in _resolve_configuration(config, explicit_sections, embedded_sections, explicit_value, accept_partial)
#     198 if not config.is_resolved():
# --> 199     _resolve_config_fields(
#     200         config, explicit_value, explicit_sections, embedded_sections, accept_partial
#     201     )
#     202 # full configuration was resolved
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\common\configuration\resolve.py:385, in _resolve_config_fields(config, explicit_values, explicit_sections, embedded_sections, accept_partial)
#     384 if unresolved_fields:
# --> 385     raise ConfigFieldMissingException(config, unresolved_fields)
#
# ConfigFieldMissingException: Missing 1 field(s) in configuration `BigQueryClientConfiguration`: `credentials`
# field `credentials` is itself a configuration `GcpServiceAccountCredentials` with missing field(s): `private_key`, `client_email` (Union 1 of 2)
#   for field `private_key` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, GYM__CREDENTIALS__PRIVATE_KEY)
#     (secrets.toml, gym.destination.bigquery.credentials.private_key)
#     (secrets.toml, gym.destination.credentials.private_key)
#     (secrets.toml, gym.credentials.private_key)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, DESTINATION__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, CREDENTIALS__PRIVATE_KEY)
#     (secrets.toml, destination.bigquery.credentials.private_key)
#     (secrets.toml, destination.credentials.private_key)
#     (secrets.toml, credentials.private_key)
#   for field `client_email` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_EMAIL)
#     (secrets.toml, gym.destination.bigquery.credentials.client_email)
#     (secrets.toml, gym.destination.credentials.client_email)
#     (secrets.toml, gym.credentials.client_email)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, CREDENTIALS__CLIENT_EMAIL)
#     (secrets.toml, destination.bigquery.credentials.client_email)
#     (secrets.toml, destination.credentials.client_email)
#     (secrets.toml, credentials.client_email)
#   NOTE: following fields in `GcpServiceAccountCredentials` got resolved: `project_id`
#
# field `credentials` is itself a configuration `GcpOAuthCredentials` with missing field(s): `client_id`, `client_secret`, `refresh_token` (Union 2 of 2)
#   for field `client_id` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_ID)
#     (secrets.toml, gym.destination.bigquery.credentials.client_id)
#     (secrets.toml, gym.destination.credentials.client_id)
#     (secrets.toml, gym.credentials.client_id)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, CREDENTIALS__CLIENT_ID)
#     (secrets.toml, destination.bigquery.credentials.client_id)
#     (secrets.toml, destination.credentials.client_id)
#     (secrets.toml, credentials.client_id)
#   for field `client_secret` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_SECRET)
#     (secrets.toml, gym.destination.bigquery.credentials.client_secret)
#     (secrets.toml, gym.destination.credentials.client_secret)
#     (secrets.toml, gym.credentials.client_secret)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, CREDENTIALS__CLIENT_SECRET)
#     (secrets.toml, destination.bigquery.credentials.client_secret)
#     (secrets.toml, destination.credentials.client_secret)
#     (secrets.toml, credentials.client_secret)
#   for field `refresh_token` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, GYM__CREDENTIALS__REFRESH_TOKEN)
#     (secrets.toml, gym.destination.bigquery.credentials.refresh_token)
#     (secrets.toml, gym.destination.credentials.refresh_token)
#     (secrets.toml, gym.credentials.refresh_token)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, DESTINATION__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, CREDENTIALS__REFRESH_TOKEN)
#     (secrets.toml, destination.bigquery.credentials.refresh_token)
#     (secrets.toml, destination.credentials.refresh_token)
#     (secrets.toml, credentials.refresh_token)
#   NOTE: following fields in `GcpOAuthCredentials` got resolved: `project_id`
#
# NOTE: following fields in `BigQueryClientConfiguration` got resolved: `location`
# Provider `secrets.toml` loaded values from locations:
# 	- C:\Users\calum\.dlt\secrets.toml
# Provider `secrets.toml` probed but not found the following locations:
# 	- C:\Users\calum\gym-analytics\.dlt\secrets.toml
# Provider `config.toml` probed but not found the following locations:
# 	- C:\Users\calum\gym-analytics\.dlt\config.toml
# 	- C:\Users\calum\.dlt\config.toml
# WARNING: provider `config.toml` is empty. Locations (i.e., files) are missing or empty.
#
# WARNING: Your run dir (C:\Users\calum\gym-analytics) is different from directory of your pipeline script (C:\Users\calum\AppData\Local\Programs\Python\Python312\Lib\site-packages).
# If you keep `.dlt` folder with secret files in the same directory as your pipeline script but run your script or a dlt cli command from some other folder, secrets/configs will not be found.
# Learn more: https://dlthub.com/docs/general-usage/credentials/
#
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[9], line 11
#       3 df2 = pd.read_csv("staged_workouts.csv")
#       5 pipeline = dlt.pipeline(
#       6     pipeline_name = "gym",
#       7     destination = "bigquery",
#       8     dataset_name = "gym_raw"
#       9 )
# ---> 11 load_info = pipeline.run(df2.to_dict(orient="records"), table_name = "workouts")
#      12 print(load_info)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:231, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     228     if trace:
#     229         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 231     step_info = f(self, *args, **kwargs)
#     232     return step_info
#     233 except Exception as ex:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:279, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     271 @wraps(f)
#     272 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     273     # add section context to the container to be used by all configuration without explicit sections resolution
#     274     with inject_section(
#     275         ConfigSectionContext(
#     276             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     277         )
#     278     ):
# --> 279         return f(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:757, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     750 # sync state with destination
#     751 if (
#     752     self.config.restore_from_destination
#     753     and not self.dev_mode
#     754     and not self._state_restored
#     755     and (self._destination or destination)
#     756 ):
# --> 757     self._sync_destination(destination, staging, dataset_name)
#     758     # sync only once
#     759     self._state_restored = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:184, in with_schemas_sync.<locals>._wrap(self, *args, **kwargs)
#     182     self._schema_storage.commit_live_schema(name)
#     183 try:
# --> 184     rv = f(self, *args, **kwargs)
#     185 except Exception:
#     186     # because we committed live schema before calling f, we may safely
#     187     # drop all changes in live schemas
#     188     for name in list(self._schema_storage.live_schemas.keys()):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\dlt\pipeline\pipeline.py:938, in Pipeline._sync_destination(self, destination, staging, dataset_name)
#     936     self._save_state(state)
#     937 except (Exception, KeyboardInterrupt) as ex:
# --> 938     raise PipelineStepFailed(self, "sync", None, ex, None) from ex
#
# PipelineStepFailed: Pipeline execution failed at `step=sync` with exception:
#
# <class 'dlt.common.configuration.exceptions.ConfigFieldMissingException'>
# Missing 1 field(s) in configuration `BigQueryClientConfiguration`: `credentials`
# field `credentials` is itself a configuration `GcpServiceAccountCredentials` with missing field(s): `private_key`, `client_email` (Union 1 of 2)
#   for field `private_key` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, GYM__CREDENTIALS__PRIVATE_KEY)
#     (secrets.toml, gym.destination.bigquery.credentials.private_key)
#     (secrets.toml, gym.destination.credentials.private_key)
#     (secrets.toml, gym.credentials.private_key)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, DESTINATION__CREDENTIALS__PRIVATE_KEY)
#     (Environment Variables, CREDENTIALS__PRIVATE_KEY)
#     (secrets.toml, destination.bigquery.credentials.private_key)
#     (secrets.toml, destination.credentials.private_key)
#     (secrets.toml, credentials.private_key)
#   for field `client_email` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_EMAIL)
#     (secrets.toml, gym.destination.bigquery.credentials.client_email)
#     (secrets.toml, gym.destination.credentials.client_email)
#     (secrets.toml, gym.credentials.client_email)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_EMAIL)
#     (Environment Variables, CREDENTIALS__CLIENT_EMAIL)
#     (secrets.toml, destination.bigquery.credentials.client_email)
#     (secrets.toml, destination.credentials.client_email)
#     (secrets.toml, credentials.client_email)
#   NOTE: following fields in `GcpServiceAccountCredentials` got resolved: `project_id`
#
# field `credentials` is itself a configuration `GcpOAuthCredentials` with missing field(s): `client_id`, `client_secret`, `refresh_token` (Union 2 of 2)
#   for field `client_id` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_ID)
#     (secrets.toml, gym.destination.bigquery.credentials.client_id)
#     (secrets.toml, gym.destination.credentials.client_id)
#     (secrets.toml, gym.credentials.client_id)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_ID)
#     (Environment Variables, CREDENTIALS__CLIENT_ID)
#     (secrets.toml, destination.bigquery.credentials.client_id)
#     (secrets.toml, destination.credentials.client_id)
#     (secrets.toml, credentials.client_id)
#   for field `client_secret` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, GYM__CREDENTIALS__CLIENT_SECRET)
#     (secrets.toml, gym.destination.bigquery.credentials.client_secret)
#     (secrets.toml, gym.destination.credentials.client_secret)
#     (secrets.toml, gym.credentials.client_secret)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, DESTINATION__CREDENTIALS__CLIENT_SECRET)
#     (Environment Variables, CREDENTIALS__CLIENT_SECRET)
#     (secrets.toml, destination.bigquery.credentials.client_secret)
#     (secrets.toml, destination.credentials.client_secret)
#     (secrets.toml, credentials.client_secret)
#   for field `refresh_token` the following (config provider, key) were tried in order:
#     (Environment Variables, GYM__DESTINATION__BIGQUERY__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, GYM__DESTINATION__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, GYM__CREDENTIALS__REFRESH_TOKEN)
#     (secrets.toml, gym.destination.bigquery.credentials.refresh_token)
#     (secrets.toml, gym.destination.credentials.refresh_token)
#     (secrets.toml, gym.credentials.refresh_token)
#     (Environment Variables, DESTINATION__BIGQUERY__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, DESTINATION__CREDENTIALS__REFRESH_TOKEN)
#     (Environment Variables, CREDENTIALS__REFRESH_TOKEN)
#     (secrets.toml, destination.bigquery.credentials.refresh_token)
#     (secrets.toml, destination.credentials.refresh_token)
#     (secrets.toml, credentials.refresh_token)
#   NOTE: following fields in `GcpOAuthCredentials` got resolved: `project_id`
#
# NOTE: following fields in `BigQueryClientConfiguration` got resolved: `location`
# Provider `secrets.toml` loaded values from locations:
# 	- C:\Users\calum\.dlt\secrets.toml
# Provider `secrets.toml` probed but not found the following locations:
# 	- C:\Users\calum\gym-analytics\.dlt\secrets.toml
# Provider `config.toml` probed but not found the following locations:
# 	- C:\Users\calum\gym-analytics\.dlt\config.toml
# 	- C:\Users\calum\.dlt\config.toml
# WARNING: provider `config.toml` is empty. Locations (i.e., files) are missing or empty.
#
# WARNING: Your run dir (C:\Users\calum\gym-analytics) is different from directory of your pipeline script (C:\Users\calum\AppData\Local\Programs\Python\Python312\Lib\site-packages).
# If you keep `.dlt` folder with secret files in the same directory as your pipeline script but run your script or a dlt cli command from some other folder, secrets/configs will not be found.
# Learn more: https://dlthub.com/docs/general-usage/credentials/
